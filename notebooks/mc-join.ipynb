# %%
import pandas as pd
import numpy as np

# %%
pca = pd.read_csv('../cleaned-data/production/PCA-data.csv', encoding='iso-8859-1', sep='\t')
clients = pd.read_csv('../cleaned-data/cleaned/moral-clients.csv', encoding='iso-8859-1', sep='\t')

# %%
pca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570180 entries, 0 to 570179
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   COMAX   570180 non-null  object
#  1   PCA-1   570180 non-null  float64
#  2   PCA-2   570180 non-null  float64
#  3   PCA-3   570180 non-null  float64
#  4   PCA-4   570180 non-null  float64
#  5   PCA-5   570180 non-null  float64
#  6   PCA-6   570180 non-null  float64
#  7   PCA-7   570180 non-null  float64
#  8   PCA-8   570180 non-null  float64
#  9   PCA-9   570180 non-null  float64
#  10  PCA-10  570180 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 47.9+ MB

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342711 entries, 0 to 3342710
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   COMAX   object
#  1   CTPE    int64
#  2   CORELB  int64
# dtypes: int64(2), object(1)
# memory usage: 76.5+ MB

# %%
clients.head(n=2)
# Out:
#         COMAX  CTPE  CORELB
# 0  6e3a2b9fa1     1       1
# 1  6e3a2b9fa1     1       1

# %%
data = pd.merge(clients,pca,on='COMAX',how='left')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3342711 entries, 0 to 3342710
# Data columns (total 13 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   COMAX   object
#  1   CTPE    int64
#  2   CORELB  int64
#  3   PCA-1   float64
#  4   PCA-2   float64
#  5   PCA-3   float64
#  6   PCA-4   float64
#  7   PCA-5   float64
#  8   PCA-6   float64
#  9   PCA-7   float64
#  10  PCA-8   float64
#  11  PCA-9   float64
#  12  PCA-10  float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 357.0+ MB

# %%
data
# Out:
#               COMAX  CTPE  CORELB     PCA-1     PCA-2     PCA-3     PCA-4  \
# 0        6e3a2b9fa1     1       1 -1.619473  0.067995 -0.194275  0.193045
# 1        6e3a2b9fa1     1       1 -1.619473  0.067995 -0.194275  0.193045
# 2        6e3a2b9fa1     1       1 -1.619473  0.067995 -0.194275  0.193045
# 3        6e3a2b9fa1     1       1 -1.619473  0.067995 -0.194275  0.193045
# 4        6e3a2b9fa1     1       1 -1.619473  0.067995 -0.194275  0.193045
# ...             ...   ...     ...       ...       ...       ...       ...
# 3342706  2ac6fa94b8     1       1  0.600369  0.572224  0.131148 -1.459051
# 3342707  2ac6fa94b8     1       1  0.600369  0.572224  0.131148 -1.459051
# 3342708  2ac6fa94b8     1       1  0.600369  0.572224  0.131148 -1.459051
# 3342709  2ac6fa94b8     1       1  0.600369  0.572224  0.131148 -1.459051
# 3342710  2ac6fa94b8     1       1  0.600369  0.572224  0.131148 -1.459051
#
#             PCA-5     PCA-6     PCA-7     PCA-8     PCA-9    PCA-10
# 0        0.966118  0.434827  0.206694 -0.604399 -0.037801 -0.132362
# 1        0.966118  0.434827  0.206694 -0.604399 -0.037801 -0.132362
# 2        0.966118  0.434827  0.206694 -0.604399 -0.037801 -0.132362
# 3        0.966118  0.434827  0.206694 -0.604399 -0.037801 -0.132362
# 4        0.966118  0.434827  0.206694 -0.604399 -0.037801 -0.132362
# ...           ...       ...       ...       ...       ...       ...
# 3342706  0.492570 -0.183194  0.970895  0.060612 -1.277924  1.041777
# 3342707  0.492570 -0.183194  0.970895  0.060612 -1.277924  1.041777
# 3342708  0.492570 -0.183194  0.970895  0.060612 -1.277924  1.041777
# 3342709  0.492570 -0.183194  0.970895  0.060612 -1.277924  1.041777
# 3342710  0.492570 -0.183194  0.970895  0.060612 -1.277924  1.041777
#
# [3342711 rows x 13 columns]

# %%
# delete nan values, aka the empty cells
data = data.dropna()

# %%
data.shape
# Out:
# (2745203, 13)

# %%
data.to_csv('../cleaned-data/production/final-mc-data.csv', sep='\t')
