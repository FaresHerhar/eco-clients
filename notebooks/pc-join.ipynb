# %%
import pandas as pd
import numpy as np

# %%
pca = pd.read_csv('../cleaned-data/production/PCA-data.csv', encoding='iso-8859-1', sep='\t')
clients = pd.read_csv('../cleaned-data/cleaned/physical-clients.csv', encoding='iso-8859-1', sep='\t')

# %%
pca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637143 entries, 0 to 637142
# Data columns (total 38 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   COMAX   637143 non-null  object
#  1   PCA-1   637143 non-null  float64
#  2   PCA-2   637143 non-null  float64
#  3   PCA-3   637143 non-null  float64
#  4   PCA-4   637143 non-null  float64
#  5   PCA-5   637143 non-null  float64
#  6   PCA-6   637143 non-null  float64
#  7   PCA-7   637143 non-null  float64
#  8   PCA-8   637143 non-null  float64
#  9   PCA-9   637143 non-null  float64
#  10  PCA-10  637143 non-null  float64
#  11  PCA-11  637143 non-null  float64
#  12  PCA-12  637143 non-null  float64
#  13  PCA-13  637143 non-null  float64
#  14  PCA-14  637143 non-null  float64
#  15  PCA-15  637143 non-null  float64
#  16  PCA-16  637143 non-null  float64
#  17  PCA-17  637143 non-null  float64
#  18  PCA-18  637143 non-null  float64
#  19  PCA-19  637143 non-null  float64
#  20  PCA-20  637143 non-null  float64
#  21  PCA-21  637143 non-null  float64
#  22  PCA-22  637143 non-null  float64
#  23  PCA-23  637143 non-null  float64
#  24  PCA-24  637143 non-null  float64
#  25  PCA-25  637143 non-null  float64
#  26  PCA-26  637143 non-null  float64
#  27  PCA-27  637143 non-null  float64
#  28  PCA-28  637143 non-null  float64
#  29  PCA-29  637143 non-null  float64
#  30  PCA-30  637143 non-null  float64
#  31  PCA-31  637143 non-null  float64
#  32  PCA-32  637143 non-null  float64
#  33  PCA-33  637143 non-null  float64
#  34  PCA-34  637143 non-null  float64
#  35  PCA-35  637143 non-null  float64
#  36  PCA-36  637143 non-null  float64
#  37  PCA-37  637143 non-null  float64
# dtypes: float64(37), object(1)
# memory usage: 184.7+ MB

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831367 entries, 0 to 831366
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   COMAX   831367 non-null  object
#  1   AGE     831367 non-null  int64
#  2   COSEXE  831367 non-null  int64
#  3   CTSCPI  831367 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 25.4+ MB

# %%
clients.head(n=2)
# Out:
#         COMAX  AGE  COSEXE  CTSCPI
# 0  6e3a2b9fa1   55       1    4600
# 1  1b44a67f61   41       0    4700

# %%
data = pd.merge(clients,pca,on='COMAX',how='left')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 831367 entries, 0 to 831366
# Data columns (total 41 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   COMAX   831367 non-null  object
#  1   AGE     831367 non-null  int64
#  2   COSEXE  831367 non-null  int64
#  3   CTSCPI  831367 non-null  int64
#  4   PCA-1   627591 non-null  float64
#  5   PCA-2   627591 non-null  float64
#  6   PCA-3   627591 non-null  float64
#  7   PCA-4   627591 non-null  float64
#  8   PCA-5   627591 non-null  float64
#  9   PCA-6   627591 non-null  float64
#  10  PCA-7   627591 non-null  float64
#  11  PCA-8   627591 non-null  float64
#  12  PCA-9   627591 non-null  float64
#  13  PCA-10  627591 non-null  float64
#  14  PCA-11  627591 non-null  float64
#  15  PCA-12  627591 non-null  float64
#  16  PCA-13  627591 non-null  float64
#  17  PCA-14  627591 non-null  float64
#  18  PCA-15  627591 non-null  float64
#  19  PCA-16  627591 non-null  float64
#  20  PCA-17  627591 non-null  float64
#  21  PCA-18  627591 non-null  float64
#  22  PCA-19  627591 non-null  float64
#  23  PCA-20  627591 non-null  float64
#  24  PCA-21  627591 non-null  float64
#  25  PCA-22  627591 non-null  float64
#  26  PCA-23  627591 non-null  float64
#  27  PCA-24  627591 non-null  float64
#  28  PCA-25  627591 non-null  float64
#  29  PCA-26  627591 non-null  float64
#  30  PCA-27  627591 non-null  float64
#  31  PCA-28  627591 non-null  float64
#  32  PCA-29  627591 non-null  float64
#  33  PCA-30  627591 non-null  float64
#  34  PCA-31  627591 non-null  float64
#  35  PCA-32  627591 non-null  float64
#  36  PCA-33  627591 non-null  float64
#  37  PCA-34  627591 non-null  float64
#  38  PCA-35  627591 non-null  float64
#  39  PCA-36  627591 non-null  float64
#  40  PCA-37  627591 non-null  float64
# dtypes: float64(37), int64(3), object(1)
# memory usage: 266.4+ MB

# %%
data.head()
# Out:
#         COMAX  AGE  COSEXE  CTSCPI     PCA-1     PCA-2     PCA-3     PCA-4  \
# 0  6e3a2b9fa1   55       1    4600 -0.646623 -0.036604  2.217052  1.189677
# 1  1b44a67f61   41       0    4700  0.125416  1.073165  0.868038 -0.562101
# 2  7e33583438   74       1    8600       NaN       NaN       NaN       NaN
# 3  b65dd1ba1d   41       0    8400       NaN       NaN       NaN       NaN
# 4  bdf1f63a98   32       1    3500  0.348781  1.062793  1.610536  2.872877
#
#       PCA-5     PCA-6  ...    PCA-28    PCA-29    PCA-30    PCA-31    PCA-32  \
# 0 -4.046703  0.198388  ... -7.684076 -1.054477  0.082188 -0.801875  0.339208
# 1 -1.432925 -0.829793  ... -0.767611 -0.859818  0.367623 -0.055811  0.160076
# 2       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4  1.810966  0.118181  ... -0.261015 -0.215323 -0.080807 -0.432228  0.395973
#
#      PCA-33    PCA-34    PCA-35    PCA-36    PCA-37
# 0 -0.071603  0.864257  0.379414 -0.140253 -0.009858
# 1  0.196749 -0.514201  0.016502 -0.028747 -0.000648
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4  0.524581 -0.378137  0.317089  0.171683  0.004463
#
# [5 rows x 41 columns]

# %%
data = data.dropna()

# %%
# save the pca data about the physical clients, intoa file to use later
data.to_csv('../cleaned-data/production/final-pc-data.csv', sep='\t')

# %%
data.shape
# Out:
# (627591, 41)
